# %%
import matplotlib.pyplot as plt
import timeit
import math
import numpy as np
from scipy import stats

# %% [markdown]
# Constant Variable

# %%
SEED = 0.1315

# %% [markdown]
# ## Von Neumann

# %%
def rng_VonNeumann(graine):
    number = str(graine*graine)
    if len(number)<=4:
        return(int(number))
    if len(number)==5:
        return(int(number[1:3]))
    if len(number)==6:
        return(int(number[1:4]))
    if len(number)==7:
        return(int(number[2:5]))
    if len(number)==8:
        return(int(number[2:5]))

# %%
def Unif_VonNeumann(Sn):
    graine = int(Sn*10000)
    return((rng_VonNeumann(graine))/10000)

# %%
Unif_VonNeumann(0.1315)
# Out:
# 0.0292

# %%
n = 10000
Sn = SEED
S = [Sn]
for i in range(n):
    Sn = Unif_VonNeumann(Sn)
    S.append(Sn)
    #print(Sn)
#plt.hist(S)
print(S)
# Out:
# [0.1315, 0.0292, 0.0052, 0.2704, 0.0062, 0.3844, 0.0776, 0.0021, 0.0441, 0.0944, 0.0911, 0.0299, 0.0094, 0.8836, 0.0074, 0.5476, 0.0986, 0.0702, 0.0928, 0.0593, 0.0516, 0.0662, 0.0382, 0.0459, 0.0106, 0.0012, 0.0121, 0.0046, 0.2116, 0.0774, 0.099, 0.0801, 0.0416, 0.073, 0.0329, 0.0082, 0.6724, 0.0212, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208, 0.0032, 0.1024, 0.0485, 0.0352, 0.0239, 0.0071, 0.5041, 0.0411, 0.0689, 0.0747, 0.058, 0.0364, 0.0324, 0.0049, 0.2401, 0.0648, 0.0199, 0.0096, 0.9025, 0.045, 0.0025, 0.0625, 0.0906, 0.0208,  ...

# %%
n = 10000
Sn = SEED
x = []
y = []
for i in range(n):
    Sn = Unif_VonNeumann(Sn)
    x.append(Sn)
    Sn = Unif_VonNeumann(Sn)
    y.append(Sn)
plt.scatter(x,y)

# %% [markdown]
# ## Congruence Generator

# %%
def generator_congruence(graine,a,b,m):
    return ((a*graine+b)%m)

def Unif_generator_congruence(Sn,a,b,m):
    graine = int(Sn*m)
    return(generator_congruence(graine,a,b,m)/m)

# %% [markdown]
# ## RANDU

# %%
def Unif_RANDU(Sn):
    return Unif_generator_congruence(Sn,65539,0,pow(2,31))

# %%
n = 10000
Sn = SEED
S = [Sn]
for i in range(n):
    Sn = Unif_RANDU(Sn)
    S.append(Sn)
    #print(Sn)
plt.hist(S)
# Out:
# (array([1008., 1005., 1007.,  965., 1041.,  958.,  973., 1012., 1030.,
#         1002.]),
#  array([3.22377309e-06, 9.99758979e-02, 1.99948572e-01, 2.99921246e-01,
#         3.99893920e-01, 4.99866595e-01, 5.99839269e-01, 6.99811943e-01,
#         7.99784617e-01, 8.99757291e-01, 9.99729965e-01]),
#  <BarContainer object of 10 artists>)

# %%
print("p value of KS test: ",stats.kstest(S,stats.uniform.cdf)[1])
# Out:
# p value of KS test:  0.7111124343971894

# %%
n = 10000
Sn = SEED
x = []
y = []
for i in range(n):
    Sn = Unif_RANDU(Sn)
    x.append(Sn)
    Sn = Unif_RANDU(Sn)
    y.append(Sn)
plt.scatter(x,y)

# %% [markdown]
# ## Standard Minimal

# %%
def Unif_StandardMininmal(Sn):
    return Unif_generator_congruence(Sn,16807,0,pow(2,31)-1)

# %%
n = 100000
Sn = 0.1315
S = [SEED]
for i in range(n):
    Sn = Unif_StandardMininmal(Sn)
    S.append(Sn)
    #print(Sn)
plt.hist(S)
# Out:
# (array([ 9921., 10104., 10151., 10039.,  9899.,  9948.,  9888., 10089.,
#         10022.,  9940.]),
#  array([1.47242099e-06, 1.00000968e-01, 2.00000463e-01, 2.99999959e-01,
#         3.99999454e-01, 4.99998949e-01, 5.99998445e-01, 6.99997940e-01,
#         7.99997436e-01, 8.99996931e-01, 9.99996427e-01]),
#  <BarContainer object of 10 artists>)

# %%
print("p value of KS test: ",stats.kstest(S,stats.uniform.cdf)[1])
# Out:
# p value of KS test:  0.6830422237572186

# %%
n = 2000
Sn = SEED
x = []
y = []
for i in range(n):
    Sn = Unif_StandardMininmal(Sn)
    x.append(Sn)
    Sn = Unif_StandardMininmal(Sn)
    y.append(Sn)
plt.scatter(x,y)

# %% [markdown]
# ## Mersenne Twister (19937)

# %% [markdown]
# Algorithm is based on Wikipedia Algorithm https://en.wikipedia.org/wiki/Mersenne_Twister

# %%
class MT19937 :
    
    def __init__(self):
        self.w, self.n, self.m, self.r = 32, 624, 397, 31
        self.a = 0x9908B0DF
        self.u, self.d = 11, 0xFFFFFFFF
        self.s, self.b = 7, 0x9D2C5680
        self.t, self.c = 15, 0xEFC60000
        self.l = 18
        self.f = 1812433253
        
        self.upper_mask = pow(2,self.w) - pow(2,self.r)
        self.lower_mask = pow(2,self.w) - 1 - self.upper_mask

        self.MT = [0 for i in range(n)]
        self.index = n

    def seed(self,seed):
        self.MT[0] = seed
        for i in range(1,n):
            temp = self.f * (self.MT[i-1] ^ (self.MT[i-1] >> (self.w-2))) + i
            self.MT[i] = temp & 0xFFFFFFFF

    def extract_number(self):
        if self.index >= n:
            self.twist()
            self.index = 0

        self.y = self.MT[self.index]
        self.y = self.y ^ ((self.y >> self.u) & self.d)
        self.y = self.y ^ ((self.y << self.t) & self.c)
        self.y = self.y ^ ((self.y << self.s) & self.b)
        self.y = self.y ^ (self.y >> self.l)

        self.index += 1
        return self.y & 0xFFFFFFFF

    def twist(self):
        for i in range(n):
            x = (self.MT[i] & self.upper_mask) + (self.MT[(i+1) % n] & self.lower_mask)
            xA = x >> 1
            if (x%2 != 0):
                xA = xA ^ self.a
            self.MT[i] = self.MT[(i + self.m)%n] ^ xA
            
    def uniform(self,n=1):
        if n==1:
            return self.extract_number()/(pow(2,32)-1)
            #return self.extract_number()
        res = []
        for i in range(n):
            res.append(self.extract_number()/(pow(2,32)-1))
            #res.append(self.extract_number())
        return res

# %%
MT = MT19937()
MT.seed(321321)

# %%
MT.uniform()
# Out:
# 0.4112173890255432

# %%
n = 100000
S = []
for i in range(n):
    S.append(MT.uniform())
    #print(Sn)
plt.hist(S)
# Out:
# (array([10045., 10032.,  9824.,  9911., 10148.,  9902.,  9915., 10036.,
#         10209.,  9978.]),
#  array([1.77400652e-05, 1.00015396e-01, 2.00013053e-01, 3.00010709e-01,
#         4.00008365e-01, 5.00006022e-01, 6.00003678e-01, 7.00001334e-01,
#         7.99998991e-01, 8.99996647e-01, 9.99994303e-01]),
#  <BarContainer object of 10 artists>)

# %%
print("p value of KS test: ",stats.kstest(S,stats.uniform.cdf)[1])
# Out:
# p value of KS test:  0.2754096802097442

# %%
x=[]
y=[]
for i in range(50):
    x.append(MT.uniform())
    y.append(MT.uniform())
plt.scatter(x,y)

# %%
dim = 100000
N = 50
x = np.zeros((dim,N))
for i in range(N):
    for j in range(dim):
        x[j,i] = MT.uniform()
plt.scatter(x[0],x[699])

# %%
plt.scatter(x[1],x[])

# %%
pow(2,32)
# Out:
# 4294967296
