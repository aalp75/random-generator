# %%
#import matplotlib.pyplot as plt
import rng

rng.set_generator('mt19937', 123)

x = rng.gaussian(4584.43214, 87.54, 10)
print(x)
# Out:
# [4575.791481855, 4578.501089982798, 4575.324657920931, 4591.738942707112, 4580.941486688832, 4576.726368620109, 4573.397827027321, 4586.347882840062, 4565.081418992731, 4575.344931402283]

# %%
print(rng.expectation(x))
print(rng.variance(x))
# Out:
# 4584.432079634238
# 87.50530480375802
