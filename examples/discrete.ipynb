# %%
import matplotlib.pyplot as plt
import rng

# %% [markdown]
# ### Bernouilli

# %%
sample = rng.bernouilli(0.3, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 0.2985
# Variance: 0.20941869186918696

# %% [markdown]
# ### Uniform discrete

# %%
sample = rng.uniform_discrete(1, 6, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 3.5193
# Variance: 2.920319541954561

# %% [markdown]
# ### Binomial

# %%
sample = rng.binomial(10, 0.3, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 2.9958
# Variance: 2.0959919591960188

# %% [markdown]
# ### Geometric

# %%
sample = rng.geometric(0.2, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 4.9172
# Variance: 19.8697311331122

# %% [markdown]
# ### Poisson

# %%
sample = rng.poisson(2, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 1.9945
# Variance: 2.0186716171617034
