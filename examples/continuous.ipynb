# %%
import matplotlib.pyplot as plt
import rng

# %% [markdown]
# ### Uniform [a, b]

# %%
sample = rng.uniform(5, 12, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 8.510531190172047
# Variance: 4.007613709772318

# %% [markdown]
# ### Exponential

# %%
sample = rng.exponential(1.5, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 0.6644349894597033
# Variance: 0.448085550629221

# %% [markdown]
# ### Gaussian
#
# ##### Scalar

# %%
sample = rng.gaussian(2, 2, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 1.9853411767881108
# Variance: 2.0079149577128845

# %% [markdown]
# #### Vector

# %%
sample = rng.gaussian_vector([[2, 3]], [[1, 0.5], [0.5, 1]], n=2)

# %% [markdown]
# ### Pareto

# %%
sample = rng.pareto(1, 6, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# Expectation: 1.2001653789342828
# Variance: 0.05833819005900325

# %% [markdown]
# ### Chi-square

# %%
sample = rng.chi2(2, size=10_000)
_ = plt.hist(sample, density=True, bins=50)
expectation = rng.expectation(sample)
variance = rng.variance(sample)
print(f'Expectation: {expectation}')
print(f'Variance: {variance}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sample = rng.chi2(2, size=10_000)
#       2 _ = plt.hist(sample, density=True, bins=50)
#       3 expectation = rng.expectation(sample)
#
# File ~/Documents/github/random-generator/.venv/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:913, in rv_generic.__call__(self, *args, **kwds)
#     912 def __call__(self, *args, **kwds):
# --> 913     return self.freeze(*args, **kwds)
#
# File ~/Documents/github/random-generator/.venv/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:908, in rv_generic.freeze(self, *args, **kwds)
#     893 """Freeze the distribution for the given arguments.
#     894
#     895 Parameters
#    (...)    905
#     906 """
#     907 if isinstance(self, rv_continuous):
# --> 908     return rv_continuous_frozen(self, *args, **kwds)
#     909 else:
#     910     return rv_discrete_frozen(self, *args, **kwds)
#
# File ~/Documents/github/random-generator/.venv/lib/python3.11/site-packages/scipy/stats/_distn_infrastructure.py:518, in rv_frozen.__init__(self, dist, *args, **kwds)
#     515 # create a new instance
#     516 self.dist = dist.__class__(**dist._updated_ctor_param())
# --> 518 shapes, _, _ = self.dist._parse_args(*args, **kwds)
#     519 self.a, self.b = self.dist._get_support(*shapes)
#
# TypeError: _parse_args() got an unexpected keyword argument 'size'
